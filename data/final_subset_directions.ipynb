# %% [markdown]
# ## Overview
# The provided instructions will allow users who are new to Python to compile a subset of data taken from the [World Bank](https://data.worldbank.org/indicator/SP.DYN.IMRT.IN).
# * This process utilizes two different `.csv` files of data to create a subset comprised of high income countries from varying geographical locations and their respective infant mortality rates from 1960 and 2021.
# * The process involves downloading the proper files, importing packages, creating a dataframe, filtering the dataframe to produce a data subset, and exporting the data subset.
# ## Getting Started
# 1. Go to the [World Bank website](https://data.worldbank.org/indicator/SP.DYN.IMRT.IN) and download the `.csv` file for global infant mortality rates.
# 2. To make data filtering easier for yourself later, rename the two `.csv` files that the World Bank provides (ex: "Infant Mortality Rates 1.csv" and "Infant Mortality Rates 2.csv ").
# 3. Save these `.csv` files to your Google Drive.
# 3. Go to Google Colab and select File and then New Notebook.
#
# ## Packages
# 1. Now you will need to mount your Google Drive to your New Notebook by using the following command:

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# 2. Import both the Numpy and Pandas packages using the following commands:

# %%
import numpy as np

# %%
import pandas as pd

# %% [markdown]
# > Note that the nicknames `np` and `pd` will make it easier to refer to these packages later in certain functions that you will use.

# %% [markdown]
# ## Creating a Dataframe
# 1. Now that you have mounted your Google Drive, you can upload your `.csv` files using the `.read_csv()` commands below:

# %%
df=pd.read_csv('gdrive/My Drive/Colab Notebooks/Infant Mortality Rates 2.csv')

# %%
df2=pd.read_csv('gdrive/My Drive/Colab Notebooks/Infant Mortality Rates 1 - Infant Mortality Rates 1.csv')

# %% [markdown]
# > Note that you can name the dataframe whatever you'd like, I just chose to use `df` and `df2` to define my dataframes.
# 2. To ensure that the dataframes properly uploaded, you can simply type the name that you used in the above commands and it should return with the data that is included in each of the `.csv` files.

# %%
df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFE                         NaN                  NaN
# 2            AFG                  South Asia           Low income
# 3            AFW                         NaN                  NaN
# 4            AGO          Sub-Saharan Africa  Lower middle income
# ..           ...                         ...                  ...
# 260          XKX       Europe & Central Asia  Upper middle income
# 261          YEM  Middle East & North Africa           Low income
# 262          ZAF          Sub-Saharan Africa  Upper middle income
# 263          ZMB          Sub-Saharan Africa  Lower middle income
# 264          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes  \
# 0                                                  NaN
# 1    26 countries, stretching from the Red Sea in t...
# 2    The reporting period for national accounts dat...
# 3    22 countries, stretching from the westernmost ...
# 4    The World Bank systematically assesses the app...
# ..                                                 ...
# 260                                                NaN
# 261  The World Bank systematically assesses the app...
# 262  Fiscal year end: March 31; reporting period fo...
# 263  National accounts data were rebased to reflect...
# 264  National Accounts data are reported in Zimbabw...
#
#                        TableName
# 0                          Aruba
# 1    Africa Eastern and Southern
# 2                    Afghanistan
# 3     Africa Western and Central
# 4                         Angola
# ..                           ...
# 260                       Kosovo
# 261                  Yemen, Rep.
# 262                 South Africa
# 263                       Zambia
# 264                     Zimbabwe
#
# [265 rows x 5 columns]

# %%
df2
# Out:
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                                      Indicator Name  Indicator Code   1960  \
# 0    Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 1    Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 2    Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 3    Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 4    Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# ..                                              ...             ...    ...
# 261  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 262  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 263  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 264  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN  121.5
# 265  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN   92.8
#
#       1961   1962   1963   1964   1965  ...       2014       2015       2016  \
# 0      NaN    NaN    NaN    NaN    NaN  ...        NaN        NaN        NaN
# 1      NaN    NaN    NaN    NaN    NaN  ...  50.858298  49.416164  48.047765
# 2      NaN    NaN  228.9  225.1  221.2  ...  55.000000  53.000000  51.100000
# 3      NaN    NaN    NaN    NaN    NaN  ...  69.988550  68.760967  67.571981
# 4      NaN    NaN    NaN    NaN    NaN  ...  60.500000  57.900000  55.700000
# ..     ...    ...    ...    ...    ...  ...        ...        ...        ...
# 261    NaN    NaN    NaN    NaN    NaN  ...  13.800000  13.000000  12.200000
# 262    NaN    NaN  278.2  272.0  265.1  ...  45.400000  46.200000  46.100000
# 263    NaN    NaN    NaN    NaN    NaN  ...  30.200000  29.400000  28.900000
# 264  119.4  117.6  116.1  114.7  113.7  ...  47.200000  47.200000  45.600000
# 265   90.6   88.4   86.1   83.8   81.6  ...  43.200000  42.100000  40.600000
#
#           2017       2018       2019       2020       2021  2022  2023
# 0          NaN        NaN        NaN        NaN        NaN   NaN   NaN
# 1    46.638627  45.268284  44.081350  43.027778  42.004211   NaN   NaN
# 2    49.400000  47.800000  46.300000  44.800000  43.400000   NaN   NaN
# 3    66.373973  64.945255  63.556011  62.165177  60.749633   NaN   NaN
# 4    53.800000  52.000000  50.400000  48.700000  47.200000   NaN   NaN
# ..         ...        ...        ...        ...        ...   ...   ...
# 261  11.500000  10.800000  10.100000   9.600000   9.100000   NaN   NaN
# 262  46.000000  46.600000  46.500000  45.800000  46.700000   NaN   NaN
# 263  28.300000  27.800000  27.300000  26.900000  26.400000   NaN   NaN
# 264  44.200000  43.600000  42.400000  41.100000  40.200000   NaN   NaN
# 265  39.500000  38.000000  37.100000  36.600000  35.700000   NaN   NaN
#
# [266 rows x 68 columns]

# %% [markdown]
# ## Filtering Data
# Now that you have uploaded your `.csv` files, it is time to filter your data!
# 1. To separate the high income countries from countries of other income levels in the dataset, use the following command:

# %%
economy=df[df["IncomeGroup"] == "High income"].copy()

# %% [markdown]
# 2. Again, reaffirm that the command worked by simply typing:

# %%
economy
# Out:
#     Country Code                      Region  IncomeGroup SpecialNotes  \
# 0            ABW   Latin America & Caribbean  High income          NaN
# 6            AND       Europe & Central Asia  High income          NaN
# 8            ARE  Middle East & North Africa  High income          NaN
# 11           ASM         East Asia & Pacific  High income          NaN
# 12           ATG   Latin America & Caribbean  High income          NaN
# ..           ...                         ...          ...          ...
# 241          TTO   Latin America & Caribbean  High income          NaN
# 249          URY   Latin America & Caribbean  High income          NaN
# 250          USA               North America  High income          NaN
# 254          VGB   Latin America & Caribbean  High income          NaN
# 255          VIR   Latin America & Caribbean  High income          NaN
#
#                   TableName
# 0                     Aruba
# 6                   Andorra
# 8      United Arab Emirates
# 11           American Samoa
# 12      Antigua and Barbuda
# ..                      ...
# 241     Trinidad and Tobago
# 249                 Uruguay
# 250           United States
# 254  British Virgin Islands
# 255   Virgin Islands (U.S.)
#
# [82 rows x 5 columns]

# %% [markdown]
# 3. Now that you know that your code worked, you can merge the second `.csv` file with the first `.csv` file using the following `pd.merge()` fuction:

# %%
mergedData = pd.merge(economy, df2, on="Country Code")

# %% [markdown]
# > Note that, in this case, the two datasets can be merged because they have a column in common: `Country Code`.
# 4. Time to make sure that your code worked:

# %%
mergedData
# Out:
#    Country Code                      Region  IncomeGroup SpecialNotes  \
# 0           ABW   Latin America & Caribbean  High income          NaN
# 1           AND       Europe & Central Asia  High income          NaN
# 2           ARE  Middle East & North Africa  High income          NaN
# 3           ASM         East Asia & Pacific  High income          NaN
# 4           ATG   Latin America & Caribbean  High income          NaN
# ..          ...                         ...          ...          ...
# 77          TTO   Latin America & Caribbean  High income          NaN
# 78          URY   Latin America & Caribbean  High income          NaN
# 79          USA               North America  High income          NaN
# 80          VGB   Latin America & Caribbean  High income          NaN
# 81          VIR   Latin America & Caribbean  High income          NaN
#
#                  TableName            Country Name  \
# 0                    Aruba                   Aruba
# 1                  Andorra                 Andorra
# 2     United Arab Emirates    United Arab Emirates
# 3           American Samoa          American Samoa
# 4      Antigua and Barbuda     Antigua and Barbuda
# ..                     ...                     ...
# 77     Trinidad and Tobago     Trinidad and Tobago
# 78                 Uruguay                 Uruguay
# 79           United States           United States
# 80  British Virgin Islands  British Virgin Islands
# 81   Virgin Islands (U.S.)   Virgin Islands (U.S.)
#
#                                     Indicator Name  Indicator Code   1960  \
# 0   Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 1   Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 2   Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN  135.5
# 3   Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
# 4   Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN   62.9
# ..                                             ...             ...    ...
# 77  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN   56.0
# 78  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN   56.6
# 79  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN   25.9
# 80  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN   68.9
# 81  Mortality rate, infant (per 1,000 live births)  SP.DYN.IMRT.IN    NaN
#
#      1961  ...  2014  2015  2016  2017  2018  2019  2020  2021  2022  2023
# 0     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     NaN  ...   3.5   3.3   3.2   3.0   2.9   2.8   2.7   2.6   NaN   NaN
# 2   128.9  ...   6.7   6.5   6.3   6.2   6.0   5.8   5.6   5.4   NaN   NaN
# 3     NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4    58.8  ...   6.8   6.5   6.2   6.0   5.7   5.5   5.3   5.2   NaN   NaN
# ..    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 77   54.3  ...  18.1  17.5  17.0  16.5  16.0  15.5  15.0  14.6   NaN   NaN
# 78   55.4  ...   8.0   7.7   7.3   6.8   6.3   5.8   5.4   5.0   NaN   NaN
# 79   25.4  ...   5.9   5.8   5.7   5.7   5.6   5.5   5.4   5.4   NaN   NaN
# 80   65.6  ...  12.3  12.0  11.6  11.3  10.9  10.6  10.3   9.9   NaN   NaN
# 81    NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [82 rows x 72 columns]

# %% [markdown]
# > As you can see, the two datasets have officially been merged!
# 5. Using the merged dataset, you will use the `.loc` function as shown below to separate out the variables that you want to use for further analysis:

# %% [markdown]
# > In this case, the variables you will isolate are `Region`, `Country Name`, `Income Group`, `1960`, and `2021`.

# %%
final_subset = mergedData.loc[:, ["Region", "Country Name", "IncomeGroup", "1960", "2021"]]

# %% [markdown]
# 6. Now it's time to ensure that your code worked properly:

# %%
final_subset
# Out:
#                         Region            Country Name  IncomeGroup   1960  \
# 0    Latin America & Caribbean                   Aruba  High income    NaN
# 1        Europe & Central Asia                 Andorra  High income    NaN
# 2   Middle East & North Africa    United Arab Emirates  High income  135.5
# 3          East Asia & Pacific          American Samoa  High income    NaN
# 4    Latin America & Caribbean     Antigua and Barbuda  High income   62.9
# ..                         ...                     ...          ...    ...
# 77   Latin America & Caribbean     Trinidad and Tobago  High income   56.0
# 78   Latin America & Caribbean                 Uruguay  High income   56.6
# 79               North America           United States  High income   25.9
# 80   Latin America & Caribbean  British Virgin Islands  High income   68.9
# 81   Latin America & Caribbean   Virgin Islands (U.S.)  High income    NaN
#
#     2021
# 0    NaN
# 1    2.6
# 2    5.4
# 3    NaN
# 4    5.2
# ..   ...
# 77  14.6
# 78   5.0
# 79   5.4
# 80   9.9
# 81   NaN
#
# [82 rows x 5 columns]

# %% [markdown]
# ## Exporting the Subset
# You have successfully filtered your original dataframes into a smaller and much more organized subset. The only thing that is left to do is to export this subset to your Google Drive using the `.to_csv()` function.
# > Use the following command:

# %%
final_subset.to_csv("final_subset.csv", index =False)

# %% [markdown]
# Check your Google Drive in the original location of your `.csv` files. Your new subset should now be here in the form of a `.csv` file!
